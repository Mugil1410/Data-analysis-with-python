# %%
from datasets import load_dataset
import pandas as pd
import matplotlib.pyplot as plt

#load data
dataSet = load_dataset('lukebarousse/data_jobs')
df = dataSet['train'].to_pandas()


#clean data
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(5)
# Out:
#               job_title_short  \
# 512570           Data Analyst
# 658119         Data Scientist
# 556012  Senior Data Scientist
# 187988      Software Engineer
# 149300          Data Engineer
#
#                                                 job_title  \
# 512570  Controller/Data Analyst Controlling Kernprozes...
# 658119                                     Data Scientist
# 556012             Senior Data Science & Python Developer
# 187988                            Software Engineer Scala
# 149300                    Data Platform Engineer Brussels
#
#                        job_location                  job_via  \
# 512570      Winterthur, Switzerland               via Indeed
# 658119  Hyderabad, Telangana, India             via LinkedIn
# 556012                     Anywhere             via LinkedIn
# 187988                Paris, France  via Emplois Trabajo.org
# 149300            Brussels, Belgium       via BeBee Belgique
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name
#return empty beacuse index has no column name initially

# %%
#check wat dataType it has

df.index.dtype
# Out:
# dtype('int64')

# %%
df_india = df[df['job_country']=='India'].drop_duplicates().copy()
df_india.reset_index(inplace=True) 
df_india
# Out:
#         index       job_title_short  \
# 0          16         Data Engineer
# 1          19        Data Scientist
# 2          29        Data Scientist
# 3          38          Data Analyst
# 4          42  Senior Data Engineer
# ...       ...                   ...
# 51075  785712         Data Engineer
# 51076  785715          Data Analyst
# 51077  785716     Software Engineer
# 51078  785718      Business Analyst
# 51079  785740     Software Engineer
#
#                                                job_title  \
# 0                                      Big Data Engineer
# 1                                         Data Scientist
# 2                                         Data Scientist
# 3                  Data Quality and Governance Analyst 1
# 4            Senior Data Engineer(Python)-1563,1637&1633
# ...                                                  ...
# 51075                     India - Collections Analyst II
# 51076  Amul Careers 2023 - Apply Online - Data Analys...
# ...

# %%
df_india.set_index('Rod',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15692\2204065368.py in ?()
# ----> 1 df_india.set_index('Rod',inplace=True)
#
# c:\Users\Booheymen\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Rod'] are in the columns"

# %%
df_india
# Out:
#              job_title_short  \
# index
# 16             Data Engineer
# 19            Data Scientist
# 29            Data Scientist
# 38              Data Analyst
# 42      Senior Data Engineer
# ...                      ...
# 785712         Data Engineer
# 785715          Data Analyst
# 785716     Software Engineer
# 785718      Business Analyst
# 785740     Software Engineer
#
#                                                 job_title  \
# index
# 16                                      Big Data Engineer
# 19                                         Data Scientist
# 29                                         Data Scientist
# 38                  Data Quality and Governance Analyst 1
# 42            Senior Data Engineer(Python)-1563,1637&1633
# ...                                                   ...
# 785712                     India - Collections Analyst II
# 785715  Amul Careers 2023 - Apply Online - Data Analys...
# 785716                        Application Support Analyst
# ...

# %%
median_pivot =  df_india.pivot_table(
    values='salary_year_avg',
    aggfunc=['median','min','max'],
    index='job_title_short'
)

# %%
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  64800.0         43200.0        142025.0
# Data Analyst                     100500.0         32400.0        650000.0
# Data Engineer                    147500.0         43200.0        249000.0
# Data Scientist                   114008.0         43200.0        204381.0
# Machine Learning Engineer         79200.0         32500.0        267000.0
# Senior Data Analyst              111175.0         64800.0        177283.0
# Senior Data Engineer             147500.0         35000.0        181765.0
# Senior Data Scientist            149653.0         64800.0        170575.0
# Software Engineer                 79200.0         44418.5        200000.0

# %%
median_pivot.sort_values(by=('median','salary_year_avg'),ascending=False)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist            149653.0         64800.0        170575.0
# Data Engineer                    147500.0         43200.0        249000.0
# Senior Data Engineer             147500.0         35000.0        181765.0
# Data Scientist                   114008.0         43200.0        204381.0
# Senior Data Analyst              111175.0         64800.0        177283.0
# Data Analyst                     100500.0         32400.0        650000.0
# Machine Learning Engineer         79200.0         32500.0        267000.0
# Software Engineer                 79200.0         44418.5        200000.0
# Business Analyst                  64800.0         43200.0        142025.0
